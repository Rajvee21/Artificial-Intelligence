# %% [markdown]
# #### CSC 215 Artificial Intelligence (Spring 2023)
#
# #### Dr. Haiquan Chen, Dept of Computer Scicence
#
# #### California State University, Sacramento

# %% [markdown]
# ## Lab 15: Natural Language Processing using NLTK and Gensim (word2vec)

# %% [markdown]
# To run the code for this lab, you need to install NLTK and Gensim using the following:
#
# * ***pip install gensim***
# * ***pip install nltk***

# %%
# do this in Google Colab

# !pip install --upgrade gensim
# !pip install --upgrade numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gensim in /usr/local/lib/python3.8/dist-packages (4.3.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.8/dist-packages (from gensim) (1.24.1)
# Requirement already satisfied: FuzzyTM>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from gensim) (2.0.5)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.8/dist-packages (from gensim) (1.7.3)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.8/dist-packages (from gensim) (6.3.0)
# Requirement already satisfied: pyfume in /usr/local/lib/python3.8/dist-packages (from FuzzyTM>=0.4.0->gensim) (0.2.25)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from FuzzyTM>=0.4.0->gensim) (1.3.5)
# Collecting numpy>=1.18.5
#   Using cached numpy-1.22.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.9 MB)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2022.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2.8.2)
# Requirement already satisfied: fst-pso in /usr/local/lib/python3.8/dist-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (1.8.1)
# Requirement already satisfied: simpful in /usr/local/lib/python3.8/dist-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (2.9.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->FuzzyTM>=0.4.0->gensim) (1.15.0)
# Requirement already satisfied: miniful in /usr/local/lib/python3.8/dist-packages (from fst-pso->pyfume->FuzzyTM>=0.4.0->gensim) (0.0.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from simpful->pyfume->FuzzyTM>=0.4.0->gensim) (2.25.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (2022.12.7)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.1
#     Uninstalling numpy-1.24.1:
#       Successfully uninstalled numpy-1.24.1
# Successfully installed numpy-1.22.4
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (1.22.4)
# Collecting numpy
#   Using cached numpy-1.24.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scipy 1.7.3 requires numpy<1.23.0,>=1.16.5, but you have numpy 1.24.1 which is incompatible.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.24.1 which is incompatible.
# Successfully installed numpy-1.24.1

# %% [markdown]
# NLTK is a leading platform released by Microsoft for building Python programs to work with human language data. NLTK has been called “a wonderful tool for teaching, and working in, computational linguistics using Python,” and “an amazing library to play with natural language.”
#
# * [NLTK](https://www.nltk.org/)
#
#
# Some simple things you can do with NLTK:
#
# * Tokenize and tag some text:
#
# * Identify named entities:
#
# * Display a parse tree:
#
#
# Gensim is a Python library for topic modelling, document indexing and similarity retrieval with large corpora
#
# * [Gensim](https://radimrehurek.com/gensim/)
#
#
#
#
# In this lab, we focus on word2vec. Word2vec is a group of models that are used to produce word embeddings. These models are ***shallow, two-layer neural networks*** that are trained to reconstruct linguistic contexts of words.
#
# #### Word2vec takes as its input a large corpus of text and produces a vector space, typically of several hundred dimensions, with each unique word in the corpus being assigned a corresponding vector in the space.
#
# Word vectors are positioned in the vector space such that ***words that share common contexts in the corpus are located in close proximity to one another in the vector space.***
#
#
#
# ## This enable math operations on words!
#
# ![Word2Vec](https://s3-ap-south-1.amazonaws.com/av-blog-media/wp-content/uploads/2017/06/06062705/Word-Vectors.png)
#
#
#
# ### Download pre-trained word embeddings:
#
#
# * [GoogleNews Vectors](https://code.google.com/archive/p/word2vec/), [GitHub Mirror](https://github.com/mmihaltz/word2vec-GoogleNews-vectors)
#
# * [Stanford GloVe](https://nlp.stanford.edu/projects/glove/)

# %% [markdown]
# ### Next we will train a Word2Vec model to get word embeddings from scratch using the provide corpus

# %%
import numpy as np
import pandas as pd

from gensim.models import Word2Vec   # if your numpy too old, update:   !pip install --upgrade numpy
from scipy import spatial

from nltk.stem.lancaster import LancasterStemmer
from nltk.tokenize import RegexpTokenizer
# Out:
# /usr/local/lib/python3.8/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ### Import training dataset
#
# https://www.kaggle.com/crowdflower/first-gop-debate-twitter-sentiment

# %%
# 2016 Republican Party presidential debate

data = pd.read_csv('data/Sentiment.csv')
data
# Out:
#           id               candidate  candidate_confidence relevant_yn  \
# 0          1  No candidate mentioned                1.0000         yes
# 1          2            Scott Walker                1.0000         yes
# 2          3  No candidate mentioned                1.0000         yes
# 3          4  No candidate mentioned                1.0000         yes
# 4          5            Donald Trump                1.0000         yes
# ...      ...                     ...                   ...         ...
# 13866  13867  No candidate mentioned                1.0000         yes
# 13867  13868           Mike Huckabee                0.9611         yes
# 13868  13869                Ted Cruz                1.0000         yes
# 13869  13870            Donald Trump                1.0000         yes
# 13870  13871                Ted Cruz                0.9242         yes
#
#        relevant_yn_confidence sentiment  sentiment_confidence  \
# 0                      1.0000   Neutral                0.6578
# 1                      1.0000  Positive                0.6333
# 2                      1.0000   Neutral                0.6629
# 3                      1.0000  Positive                1.0000
# 4                      1.0000  Positive                0.7045
# ...                       ...       ...                   ...
# 13866                  1.0000  Negative                0.7991
# 13867                  1.0000  Positive                0.7302
# 13868                  1.0000  Positive                0.8051
# 13869                  1.0000  Negative                1.0000
# 13870                  0.9614  Positive                0.9614
#
#                              subject_matter  subject_matter_confidence  \
# 0                         None of the above                     1.0000
# 1                         None of the above                     1.0000
# 2                         None of the above                     0.6629
# 3                         None of the above                     0.7039
# 4                         None of the above                     1.0000
# ...                                     ...                        ...
# 13866                              Abortion                     0.6014
# 13867                     None of the above                     0.9229
# 13868                     None of the above                     0.9647
# 13869  Women's Issues (not abortion though)                     0.9202
# 13870                     None of the above                     0.9242
#
#                candidate_gold  ... relevant_yn_gold retweet_count  \
# 0                         NaN  ...              NaN             5
# 1                         NaN  ...              NaN            26
# 2                         NaN  ...              NaN            27
# 3                         NaN  ...              NaN           138
# 4                         NaN  ...              NaN           156
# ...                       ...  ...              ...           ...
# 13866  No candidate mentioned  ...              yes             7
# 13867           Mike Huckabee  ...              yes             1
# 13868                Ted Cruz  ...              yes            67
# 13869            Donald Trump  ...              yes           149
# 13870                Ted Cruz  ...              yes            65
#
#           sentiment_gold                             subject_matter_gold  \
# 0                    NaN                                             NaN
# 1                    NaN                                             NaN
# 2                    NaN                                             NaN
# 3                    NaN                                             NaN
# 4                    NaN                                             NaN
# ...                  ...                                             ...
# 13866           Negative  Abortion\nWomen's Issues (not abortion though)
# 13867                NaN                                             NaN
# 13868  Positive\nNeutral                                             NaN
# 13869                NaN            Women's Issues (not abortion though)
# 13870           Positive                                             NaN
#
#                                                     text tweet_coord  \
# 0      RT @NancyLeeGrahn: How did everyone feel about...         NaN
# 1      RT @ScottWalker: Didn't catch the full #GOPdeb...         NaN
# 2      RT @TJMShow: No mention of Tamir Rice and the ...         NaN
# 3      RT @RobGeorge: That Carly Fiorina is trending ...         NaN
# 4      RT @DanScavino: #GOPDebate w/ @realDonaldTrump...         NaN
# ...                                                  ...         ...
# 13866  RT @cappy_yarbrough: Love to see men who will ...         NaN
# 13867  RT @georgehenryw: Who thought Huckabee exceede...         NaN
# 13868  RT @Lrihendry: #TedCruz As President, I will a...         NaN
# 13869  RT @JRehling: #GOPDebate Donald Trump says tha...         NaN
# 13870  RT @Lrihendry: #TedCruz headed into the Presid...         NaN
#
#                    tweet_created            tweet_id   tweet_location  \
# 0      2015-08-07 09:54:46 -0700  629697200650592256              NaN
# 1      2015-08-07 09:54:46 -0700  629697199560069120              NaN
# 2      2015-08-07 09:54:46 -0700  629697199312482304              NaN
# 3      2015-08-07 09:54:45 -0700  629697197118861312            Texas
# 4      2015-08-07 09:54:45 -0700  629697196967903232              NaN
# ...                          ...                 ...              ...
# 13866  2015-08-07 09:29:43 -0700  629690895479250944             Como
# 13867  2015-08-07 09:25:02 -0700  629689719056568320              USA
# 13868  2015-08-07 07:19:18 -0700  629658075784282112              NaN
# 13869  2015-08-07 09:54:04 -0700  629697023663546368              NaN
# 13870  2015-08-06 18:22:27 -0700  629462573641920512  San Antonio, TX
#
#                     user_timezone
# 0                           Quito
# 1                             NaN
# 2                             NaN
# 3      Central Time (US & Canada)
# 4                         Arizona
# ...                           ...
# 13866                         NaN
# 13867                         NaN
# 13868                         NaN
# 13869                         NaN
# 13870  Central Time (US & Canada)
#
# [13871 rows x 21 columns]

# %%
data = data[['text','sentiment']]
data = data[data.sentiment != "Neutral" ] 
data = data[~data.text.str.startswith('RT')].reset_index(drop=True)

# %%
data
# Out:
#                                                    text sentiment
# 0     Deer in the headlights RT @lizzwinstead: Ben C...  Negative
# 1     @JGreenDC @realDonaldTrump In all fairness #Bi...  Negative
# 2     Me reading my family's comments about how grea...  Negative
# 3     Hey @ChrisChristie exploiting the tragedy of 9...  Negative
# 4     reason comment is funny 'in case you're ignora...  Negative
# ...                                                 ...       ...
# 4586  This is why I don't watch Fox News, they're al...  Negative
# 4587  @marcorubio came out of the gate like a true l...  Positive
# 4588  Best line of #GOPDebate was "Immigration witho...  Positive
# 4589  People who say they are #prolife are usually a...  Negative
# 4590  So trans soldiers can die for you Huckabee but...  Negative
#
# [4591 rows x 2 columns]

# %% [markdown]
# ### Preprocess data (tokenize text)
# - Convert all letters into lowercase
# - Remove punctuations, numbers, etc.

# %%
tkr = RegexpTokenizer('[a-zA-Z]+')
#stemmer = LancasterStemmer()

# %%
data['tokenized'] = data['text'].apply(lambda row: [t.lower() for t in tkr.tokenize(row)])

#data['tokenized'] = data['text'].apply(lambda row: [stemmer.stem(t.lower()) for t in tkr.tokenize(row)])

# %%
data['tokenized']
# Out:
# 0       [deer, in, the, headlights, rt, lizzwinstead, ...
# 1       [jgreendc, realdonaldtrump, in, all, fairness,...
# 2       [me, reading, my, family, s, comments, about, ...
# 3       [hey, chrischristie, exploiting, the, tragedy,...
# 4       [reason, comment, is, funny, in, case, you, re...
#                               ...
# 4586    [this, is, why, i, don, t, watch, fox, news, t...
# 4587    [marcorubio, came, out, of, the, gate, like, a...
# 4588    [best, line, of, gopdebate, was, immigration, ...
# 4589    [people, who, say, they, are, prolife, are, us...
# 4590    [so, trans, soldiers, can, die, for, you, huck...
# Name: tokenized, Length: 4591, dtype: object

# %%
tweets = data['tokenized']
print(tweets[0])    
print(tweets[1])    
print(tweets[2])
# Out:
# ['deer', 'in', 'the', 'headlights', 'rt', 'lizzwinstead', 'ben', 'carson', 'may', 'be', 'the', 'only', 'brain', 'surgeon', 'who', 'has', 'performed', 'a', 'lobotomy', 'on', 'himself', 'gopdebate']
# ['jgreendc', 'realdonaldtrump', 'in', 'all', 'fairness', 'billclinton', 'owns', 'that', 'phrase', 'gopdebate']
# ['me', 'reading', 'my', 'family', 's', 'comments', 'about', 'how', 'great', 'the', 'gopdebate', 'was', 'http', 't', 'co', 'giagjpygxz']

# %% [markdown]
# ### Create and train model
# - Create a word2vec model and train it with the corpus
# - Key parameter description (https://radimrehurek.com/gensim/models/word2vec.html)
#     - **sentences**: training data (***has to be a list with tokenized sentences***)
#     - **vector_size (formerly: size)**: dimension of embedding space
#     - **sg**: Continuous Bag-of-Words model (CBOW) if 0 and the Skip-Gram model if 1. CBOW creates a sliding window around current word, to predict it from “context” — the surrounding words.  Skip-Gram model is actaully the opposite of CBOW. Instead of prediciting one word each time, we use 1 word to predict all surrounding words (“context”).
#     - **window**: number of words accounted for each context (if the window size is 3, 3 word in the left neighorhood and 3 word in the right neighborhood are considered)
#     - **min_count**: Ignores all words with total frequency lower than this
#     - **epochs (formerly: iter)**: number of training iterations
#     - **workers**: number of worker threads to train (if multicore machines)
#
# For details,  go to http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/

# %%
model = Word2Vec(sentences = tweets, vector_size = 128, sg = 1, window = 3, min_count = 1, epochs = 10)

# %% [markdown]
# ### Normalize all the derived word vectors so they have equal length (optional if you use Gensim 4.0)

# %%
model.init_sims(replace = True)   # normalize all word vectors so they have equal length

# Note that you cannot continue training after doing a replace. 
# The model becomes effectively read-only = you can call most_similar, similarity etc., but not train.
# Out:
# <ipython-input-10-3b5e25a60e33>:1: DeprecationWarning: Call to deprecated `init_sims` (Gensim 4.0.0 implemented internal optimizations that make calls to init_sims() unnecessary. init_sims() is now obsoleted and will be completely removed in future versions. See https://github.com/RaRe-Technologies/gensim/wiki/Migrating-from-Gensim-3.x-to-4).
#   model.init_sims(replace = True)   # normalize all word vectors so they have equal length
# WARNING:gensim.models.keyedvectors:destructive init_sims(replace=True) deprecated & no longer required for space-efficiency

# %% [markdown]
# ### Save and load model
# - word2vec model can be saved and loaded locally
# - Doing so can reduce time to train model again

# %%
model.save('word2vec_model')

# %%
model = Word2Vec.load('word2vec_model')

# %% [markdown]
# ### Once the model is trained, it is accessible via the “wv” attribute.
#
# #### The ***wv*** property of the word2vec model holds all trained word vectors.

# %%
X_vecs = model.wv

# %% [markdown]
# ### You can print the learned vocabulary of tokens (words) as follows:

# %%
words = list(model.wv.index_to_key)
words
# Out:
# ['gopdebate',
#  'the',
#  't',
#  'gopdebates',
#  'to',
#  'a',
#  'i',
#  'co',
#  'of',
#  'is',
#  's',
#  'and',
#  'http',
#  'trump',
#  'in',
#  'it',
#  'you',
#  'that',
#  'for',
#  'on',
#  'was',
#  'last',
#  'night',
#  'he',
#  'not',
#  'this',
#  'about',
#  'realdonaldtrump',
#  'https',
#  'amp',
#  'but',
#  'debate',
#  'like',
#  'be',
#  'at',
#  'are',
#  'with',
#  'gop',
#  'they',
#  'foxnews',
#  'megynkelly',
#  'all',
#  'have',
#  'so',
#  'my',
#  'can',
#  'we',
#  'who',
#  'just',
#  'what',
#  'as',
#  'from',
#  'if',
#  'me',
#  'his',
#  'm',
#  'fox',
#  'candidates',
#  'no',
#  'how',
#  'did',
#  'up',
#  'out',
#  'more',
#  'people',
#  'one',
#  'donald',
#  'when',
#  'or',
#  'your',
#  'don',
#  'has',
#  'questions',
#  'think',
#  'by',
#  'an',
#  'news',
#  'were',
#  'do',
#  'after',
#  'rubio',
#  'only',
#  'time',
#  'would',
#  'why',
#  'get',
#  'god',
#  'carson',
#  'him',
#  'women',
#  'will',
#  'really',
#  'should',
#  'good',
#  'than',
#  'kasich',
#  'know',
#  'tcot',
#  'these',
#  'cruz',
#  'jeb',
#  'their',
#  'bush',
#  'now',
#  'great',
#  'watching',
#  'republican',
#  'won',
#  'want',
#  'say',
#  'didn',
#  'any',
#  'party',
#  're',
#  'she',
#  'question',
#  'u',
#  'walker',
#  'see',
#  'watch',
#  'real',
#  'them',
#  'some',
#  'huckabee',
#  'there',
#  'carlyfiorina',
#  'had',
#  'said',
#  'need',
#  'best',
#  'most',
#  'her',
#  'much',
#  'got',
#  'd',
#  'going',
#  'president',
#  'us',
#  'via',
#  'our',
#  'megyn',
#  'candidate',
#  'too',
#  'kelly',
#  'w',
#  'right',
#  'make',
#  'christie',
#  'america',
#  'chris',
#  'donaldtrump',
#  'hillary',
#  'show',
#  'because',
#  'very',
#  'being',
#  'paul',
#  'randpaul',
#  'job',
#  'talking',
#  'vote',
#  'go',
#  'even',
#  'better',
#  'does',
#  'first',
#  'take',
#  'moderators',
#  'other',
#  'could',
#  'well',
#  'love',
#  'ben',
#  'made',
#  'never',
#  've',
#  'been',
#  'over',
#  'doesn',
#  'next',
#  'country',
#  'rand',
#  'during',
#  'man',
#  'says',
#  'new',
#  'carly',
#  'marcorubio',
#  'republicans',
#  'realbencarson',
#  'tonight',
#  'sure',
#  'way',
#  'anyone',
#  'stage',
#  'p',
#  'fiorina',
#  'still',
#  'debates',
#  'life',
#  'let',
#  'thing',
#  'big',
#  'talk',
#  'then',
#  'rt',
#  'am',
#  'where',
#  'actually',
#  'everyone',
#  'many',
#  'political',
#  'presidential',
#  'issues',
#  'look',
#  'off',
#  'winner',
#  'bad',
#  'jebbush',
#  'marco',
#  'back',
#  'b',
#  'same',
#  'someone',
#  'trying',
#  'down',
#  'r',
#  'obama',
#  'lol',
#  'oh',
#  'johnkasich',
#  'chrischristie',
#  'american',
#  'here',
#  'election',
#  'o',
#  'guy',
#  'thought',
#  'keep',
#  'ted',
#  'c',
#  'things',
#  'media',
#  'abortion',
#  'war',
#  'tedcruz',
#  'call',
#  'give',
#  'woman',
#  'll',
#  'every',
#  'answer',
#  'men',
#  'watched',
#  'win',
#  'th',
#  'day',
#  'hard',
#  'potus',
#  'ask',
#  'makes',
#  'run',
#  'needs',
#  'scottwalker',
#  'wants',
#  'cnn',
#  'point',
#  'hillaryclinton',
#  'calling',
#  'politics',
#  'dr',
#  'nothing',
#  'mean',
#  'those',
#  'rights',
#  'social',
#  'put',
#  'fact',
#  'bencarson',
#  'into',
#  'clinton',
#  'democrats',
#  'tv',
#  'military',
#  'immigration',
#  'please',
#  'shit',
#  'again',
#  'care',
#  'saying',
#  'morning',
#  'govmikehuckabee',
#  'two',
#  'feel',
#  'biggest',
#  'which',
#  'fun',
#  'f',
#  'twitter',
#  'fair',
#  'black',
#  'away',
#  'yes',
#  'foxdebate',
#  'wasn',
#  'john',
#  'loved',
#  'world',
#  'scott',
#  'tell',
#  'ever',
#  'white',
#  'asked',
#  'politicians',
#  'change',
#  'stop',
#  'k',
#  'problem',
#  'x',
#  'come',
#  'n',
#  'wait',
#  'thank',
#  'true',
#  'its',
#  'called',
#  'lot',
#  'getting',
#  'conservative',
#  'against',
#  'gets',
#  'money',
#  'democrat',
#  'race',
#  'q',
#  'something',
#  'winners',
#  'audience',
#  'seriously',
#  'maybe',
#  'blacklivesmatter',
#  'today',
#  'ww',
#  'hear',
#  'bernie',
#  'illegal',
#  'e',
#  'wow',
#  'wallace',
#  'support',
#  'gave',
#  'looks',
#  'j',
#  'clear',
#  'else',
#  'person',
#  'less',
#  'reagan',
#  'hair',
#  'hey',
#  'reality',
#  'anything',
#  'auhlnza',
#  'pretty',
#  'break',
#  'little',
#  'saw',
#  'word',
#  'agree',
#  'bretbaier',
#  'frankluntz',
#  'lost',
#  'comments',
#  'own',
#  'pimps',
#  'youtube',
#  'wrong',
#  'mention',
#  'isn',
#  'moderator',
#  'hate',
#  'nights',
#  'part',
#  'enough',
#  'game',
#  'running',
#  'came',
#  'loser',
#  'far',
#  'believe',
#  'fat',
#  'attack',
#  'pro',
#  'end',
#  'stupid',
#  'entertaining',
#  'foxnewsdebate',
#  'tough',
#  'each',
#  'primary',
#  'guys',
#  'face',
#  'hope',
#  'deal',
#  'before',
#  'performance',
#  'gay',
#  'killing',
#  'sense',
#  'couldn',
#  'looking',
#  'live',
#  'y',
#  'mike',
#  'thanks',
#  'also',
#  'asking',
#  'times',
#  'misogyny',
#  'must',
#  'seems',
#  'climate',
#  'kill',
#  'rosie',
#  'thinks',
#  'while',
#  'matter',
#  'americans',
#  'help',
#  'gt',
#  'tax',
#  'iran',
#  'voting',
#  'ratings',
#  'old',
#  'wins',
#  'fuck',
#  'ccot',
#  'class',
#  'done',
#  'may',
#  'long',
#  'st',
#  'kind',
#  'both',
#  'correct',
#  'around',
#  'poor',
#  'funny',
#  'disappointed',
#  'told',
#  'years',
#  'seen',
#  'went',
#  'left',
#  'stand',
#  'bunch',
#  'truth',
#  'whole',
#  'himself',
#  'top',
#  'missed',
#  'speak',
#  'bimbo',
#  'took',
#  'damn',
#  'voters',
#  'respect',
#  'instead',
#  'gonna',
#  'line',
#  'losers',
#  'state',
#  'showed',
#  'having',
#  'focus',
#  'everything',
#  'tweets',
#  'dems',
#  'mentioned',
#  'set',
#  'start',
#  'games',
#  'attacks',
#  'making',
#  'mexican',
#  'closing',
#  'find',
#  'conservatives',
#  'name',
#  'doing',
#  'record',
#  'joke',
#  'nice',
#  'until',
#  'g',
#  'read',
#  'answers',
#  'gopclowncar',
#  'facebook',
#  'campaign',
#  'hilarious',
#  'giving',
#  'alien',
#  'forward',
#  'mr',
#  'use',
#  'heard',
#  'important',
#  'marriage',
#  'impressed',
#  'words',
#  'seem',
#  'work',
#  'miss',
#  'gov',
#  'planned',
#  'parenthood',
#  'without',
#  'interesting',
#  'between',
#  'none',
#  'another',
#  'group',
#  'ass',
#  'comedy',
#  'order',
#  'personal',
#  'v',
#  'used',
#  'dream',
#  'ok',
#  'sad',
#  'field',
#  'might',
#  'statement',
#  'l',
#  'anymore',
#  'brain',
#  'play',
#  'farrakhan',
#  'vs',
#  'least',
#  'fucking',
#  'lfy',
#  'lklffn',
#  'bor',
#  'future',
#  'thinking',
#  'msnbc',
#  'security',
#  'moment',
#  'issue',
#  'air',
#  'probably',
#  'high',
#  'rnc',
#  'full',
#  'ridiculous',
#  'yeah',
#  'proud',
#  'history',
#  'post',
#  'single',
#  'berniesanders',
#  'entertainment',
#  'policy',
#  'brought',
#  'wish',
#  'hangover',
#  'crazy',
#  'once',
#  'points',
#  'pjnet',
#  'dear',
#  'though',
#  'prostitutes',
#  'liberal',
#  'h',
#  'plan',
#  'favorite',
#  'wonder',
#  'hand',
#  'ppl',
#  'scary',
#  'ronald',
#  'always',
#  'biased',
#  'learned',
#  'become',
#  'racist',
#  'rich',
#  'calls',
#  'kids',
#  'mess',
#  'speaking',
#  'circus',
#  'half',
#  'pc',
#  'sound',
#  'year',
#  'rd',
#  'place',
#  'head',
#  'under',
#  'movement',
#  'idiots',
#  'correctness',
#  'usa',
#  'huge',
#  'completely',
#  'glad',
#  'dc',
#  'bring',
#  'politically',
#  'stewart',
#  'turn',
#  'russia',
#  'since',
#  'human',
#  'comment',
#  'hates',
#  'government',
#  'nd',
#  'terrible',
#  'nomination',
#  'office',
#  'sexist',
#  'free',
#  'guess',
#  'balanced',
#  'hands',
#  'debatewithbernie',
#  'cut',
#  'comes',
#  'pick',
#  'definitely',
#  'happened',
#  'realize',
#  'morningjoe',
#  'dad',
#  'coming',
#  'z',
#  'wouldn',
#  'chance',
#  'yet',
#  'stuff',
#  'disgusting',
#  'liberals',
#  'common',
#  'already',
#  'tried',
#  'shame',
#  'rush',
#  'analysis',
#  'thoughts',
#  'minutes',
#  'talked',
#  'remember',
#  'jon',
#  'primaries',
#  'check',
#  'abt',
#  'listen',
#  'leader',
#  'system',
#  'church',
#  'pay',
#  'jesus',
#  'dog',
#  'pig',
#  'polls',
#  'finally',
#  'rhetoric',
#  'round',
#  'control',
#  'bill',
#  'drink',
#  'uniteblue',
#  'perfect',
#  'sex',
#  'lots',
#  'obviously',
#  'straight',
#  'playing',
#  'police',
#  'gun',
#  'republicandebate',
#  'numbers',
#  'others',
#  'knew',
#  'baby',
#  'recap',
#  'em',
#  'except',
#  'jonvoyage',
#  'attacking',
#  'kept',
#  'takeaway',
#  'quite',
#  'lives',
#  'fire',
#  'boy',
#  'public',
#  'few',
#  'cancel',
#  'looked',
#  'anointed',
#  'mind',
#  'cool',
#  'became',
#  'rwsurfergirl',
#  'bias',
#  'smart',
#  'fix',
#  'excellent',
#  'fan',
#  'states',
#  'through',
#  'based',
#  'fight',
#  'amazing',
#  'worse',
#  'makeamericagreatagain',
#  'ur',
#  'act',
#  'sorry',
#  'surprised',
#  'ignorant',
#  'changed',
#  'fail',
#  'knows',
#  'billhemmer',
#  'past',
#  'outnumbered',
#  'mouth',
#  'hunger',
#  'hearing',
#  'friends',
#  'such',
#  'frank',
#  'drinking',
#  'plannedparenthood',
#  'destroy',
#  'abortions',
#  'sanders',
#  'leave',
#  'try',
#  'different',
#  'anti',
#  'statements',
#  'idea',
#  'lose',
#  'florida',
#  'total',
#  'hell',
#  'jobs',
#  'proved',
#  'reason',
#  'goptbt',
#  'cop',
#  'answering',
#  'aren',
#  'christian',
#  'ha',
#  'response',
#  'obamacare',
#  'working',
#  'means',
#  'lie',
#  'trumps',
#  'early',
#  'listening',
#  'power',
#  'shut',
#  'hit',
#  'awesome',
#  'dont',
#  'rushlimbaugh',
#  'serious',
#  'worst',
#  'hurt',
#  'super',
#  'unprofessional',
#  'ff',
#  'wanted',
#  'lead',
#  'goes',
#  'hours',
#  'topics',
#  'touch',
#  'ohio',
#  'liked',
#  'enjoyed',
#  'speaks',
#  'coverage',
#  'wtf',
#  'honestly',
#  'shouldn',
#  'gone',
#  'reading',
#  'lies',
#  'themselves',
#  'sentedcruz',
#  'awful',
#  'leaders',
#  'family',
#  'dumb',
#  'substance',
#  'failed',
#  'ya',
#  'veterans',
#  'female',
#  'health',
#  'scared',
#  'brilliant',
#  'die',
#  'business',
#  'video',
#  'blah',
#  'canttrustabush',
#  'sexism',
#  'lack',
#  'problems',
#  'deserve',
#  'rather',
#  'hardball',
#  'either',
#  'second',
#  'everybody',
#  'imwithhuck',
#  'host',
#  'buy',
#  'amendment',
#  'donnell',
#  'angry',
#  'clowns',
#  'fb',
#  'credit',
#  'tomorrow',
#  'foreign',
#  'rest',
#  'given',
#  'lt',
#  'beat',
#  'mad',
#  'marthamaccallum',
#  'supporters',
#  'govchristie',
#  'self',
#  'car',
#  'takes',
#  'laugh',
#  'zero',
#  'poll',
#  'afraid',
#  'folks',
#  'general',
#  'stay',
#  'close',
#  'idiot',
#  'punch',
#  'basically',
#  'breaking',
#  'faithful',
#  'shocks',
#  'spot',
#  'independent',
#  'friend',
#  'happy',
#  'okay',
#  'food',
#  'handle',
#  'professional',
#  'fear',
#  'dwstweets',
#  'almost',
#  'finished',
#  'wedding',
#  'internet',
#  'tlot',
#  'shot',
#  'trust',
#  'killed',
#  'national',
#  'needed',
#  'laughing',
#  'religion',
#  'movie',
#  'isis',
#  'days',
#  'middle',
#  'evening',
#  'awkward',
#  'omg',
#  'demagog',
#  'views',
#  'nobody',
#  'climatechange',
#  'lady',
#  'lets',
#  'results',
#  'teaparty',
#  'side',
#  'understand',
#  'shows',
#  'shocked',
#  'low',
#  'team',
#  'faith',
#  'elected',
#  'horrible',
#  'winning',
#  'cruzcrew',
#  'sick',
#  'according',
#  'fired',
#  'instagram',
#  'china',
#  'ones',
#  'luntz',
#  'taxes',
#  'hilary',
#  'showing',
#  'king',
#  'attempt',
#  'advice',
#  'kkkorgop',
#  'hot',
#  'obvious',
#  'fighter',
#  'totally',
#  'course',
#  'father',
#  'reform',
#  'nominee',
#  'missing',
#  'snl',
#  'voter',
#  'policies',
#  'disappointing',
#  'report',
#  'tweeting',
#  'held',
#  'prez',
#  'perry',
#  'children',
#  'sounds',
#  'jindal',
#  'behind',
#  'va',
#  'economy',
#  'advantage',
#  'choice',
#  'gotta',
#  'wakeupamerica',
#  'quality',
#  'spoke',
#  'million',
#  'move',
#  'crap',
#  'substantive',
#  'proof',
#  'summary',
#  'simply',
#  'discussing',
#  'bit',
#  'feelthebern',
#  'talks',
#  'bullshit',
#  'actual',
#  'reminds',
#  'paid',
#  'ygmgbavqut',
#  'non',
#  'internationalbeerday',
#  'taking',
#  'bgzysysfsu',
#  'learn',
#  'forget',
#  'clowncar',
#  'civil',
#  'presidentialdebate',
#  'standwithrand',
#  'mikehuckabeegop',
#  'impressive',
#  'career',
#  'dumptrump',
#  'progressive',
#  'prove',
#  'letting',
#  'etc',
#  'laws',
#  'treated',
#  'admit',
#  'drunk',
#  'bully',
#  'sadly',
#  'kimguilfoyle',
#  'seeing',
#  ...]

# %%
print ('trump' in words)
# Out:
# True

# %%
print(model.wv['trump'])
print(model.wv['trump'].shape)
# Out:
# [ 0.03349504 -0.04257391 -0.01241147  0.08473593  0.09193628  0.00250722
#   0.04860888  0.0785149  -0.09423184  0.04285305  0.09216811 -0.11547117
#   0.00734323 -0.01464565  0.15262897  0.08627716 -0.05485145  0.03828108
#  -0.0142516  -0.04458943  0.04672495  0.12381701  0.00163646 -0.15341294
#  -0.12056599 -0.06133847 -0.05325154  0.11909362  0.13320418  0.05845943
#  -0.0707586   0.1438664  -0.09212553 -0.00732785 -0.1591769   0.05757797
#   0.17115906  0.08361261  0.13478763 -0.05267585  0.04322574  0.01830761
#   0.03495894 -0.02452877  0.04426668 -0.00721593 -0.07042611 -0.18496332
#   0.06080728 -0.00371308  0.09611719 -0.04782627  0.11422641  0.11177275
#   0.10654738 -0.00759606  0.22715497 -0.03908908 -0.09738907 -0.03214465
#  -0.04792882 -0.0754894   0.07186405 -0.00287175  0.10343757 -0.07429752
#   0.00441283  0.0359907  -0.06266224 -0.0785659   0.080979   -0.01882071
#  -0.19112276  0.00942762  0.07876293 -0.15119855  0.0207716  -0.08172785
#  -0.06769384  0.15542078  0.01994049 -0.03418295 -0.0278975   0.15768853
#   0.11238921  0.09726711  0.16549662 -0.0304317   0.19169512  0.06249845
#  -0.03323002 -0.062243    0.06497668 -0.01830884  0.08379483  0.08613528
#  -0.1733635  -0.17405103 -0.1493639  -0.03003552 -0.03924407  0.08516175
#  -0.05365328 -0.0224447   0.10034434  0.00059222  0.02849391 -0.07841771
#   0.08753283  0.05822563  0.06128315 -0.01318641  0.10081607  0.10143004
#  -0.01719704  0.1390315  -0.0078607   0.1404363   0.15296446  0.03477005
#   0.0318371   0.04854307  0.06808913  0.01567787 -0.01189368 -0.07323209
#  -0.02797114  0.07470353]
# (128,)

# %% [markdown]
# Why 128?

# %% [markdown]
# ### Similarity calculation
#
# - Similarity between embedded words (i.e., vectors) can be computed using metrics such as cosine similarity

# %%
model.wv.most_similar('trump')
# Out:
# [('preview', 0.8394254446029663),
#  ('donald', 0.8279519081115723),
#  ('trumps', 0.8120870590209961),
#  ('insulted', 0.8016189932823181),
#  ('wins', 0.7937921285629272),
#  ('jebbush', 0.7878875732421875),
#  ('sexist', 0.7866778373718262),
#  ('bringbackdarrellhammond', 0.7820214033126831),
#  ('bimbo', 0.780591607093811),
#  ('obviously', 0.7796945571899414)]

# %%
v1 = model.wv['ted']
v2 = model.wv['trump']

# %%
# define a function that computes cosine similarity between two words
def cosine_similarity(v1, v2):
    return 1 - spatial.distance.cosine(v1, v2)

# %%
cosine_similarity(v1, v2)
# Out:
# 0.7444007396697998

# %% [markdown]
# words similar to ['ted', 'trump'] but disimilar to ['cnn']

# %%
model.wv.most_similar(positive=['ted', 'trump'], negative=['cnn'])
# Out:
# [('cruz', 0.7120761871337891),
#  ('kasich', 0.6357433795928955),
#  ('huckabee', 0.6288331151008606),
#  ('carson', 0.6092767715454102),
#  ('donald', 0.6077600717544556),
#  ('ben', 0.6065826416015625),
#  ('dear', 0.6032679080963135),
#  ('john', 0.6012837886810303),
#  ('says', 0.599044919013977),
#  ('dr', 0.5922253131866455)]

# %% [markdown]
# ### Use word2vec result as input data to train a neural network model.
#
# #### Now each tweet can be "treated as 2-D array".  Let's take the first tweet as example

# %%
[token for token in tweets[0]]
# Out:
# ['deer',
#  'in',
#  'the',
#  'headlights',
#  'rt',
#  'lizzwinstead',
#  'ben',
#  'carson',
#  'may',
#  'be',
#  'the',
#  'only',
#  'brain',
#  'surgeon',
#  'who',
#  'has',
#  'performed',
#  'a',
#  'lobotomy',
#  'on',
#  'himself',
#  'gopdebate']

# %%
len(tweets[0])
# Out:
# 22

# %%
for t, token in enumerate(tweets[0]):
    print(model.wv[token])
# Out:
# [ 0.01527211 -0.13625318  0.05632527  0.02510232  0.07749157 -0.07799084
#  -0.00305168  0.01561658 -0.03489351  0.16915986  0.10616387 -0.08212677
#  -0.0653687  -0.04441346  0.04029745  0.09241129 -0.0825252   0.09331887
#  -0.11898465  0.07169112  0.12186944  0.14663832 -0.02138282 -0.14636658
#  -0.12227961  0.06027051 -0.06814151  0.09819517  0.04018774 -0.04638248
#  -0.03833468  0.08404088  0.02917851 -0.00840866 -0.0544882   0.00889804
#   0.21430561  0.00781945  0.04715935  0.01726187  0.0054331   0.14732233
#  -0.02693737 -0.07024334  0.123269    0.05579787 -0.07234985 -0.04271977
#   0.04152122  0.06560847  0.06062153  0.05837453  0.06174793  0.09771547
#   0.02155089  0.04507793  0.22670943  0.01411681 -0.05886986  0.09373379
#  -0.08763298  0.00363162  0.0982978  -0.0119391   0.15804315 -0.01351247
#   0.02905325  0.0087295  -0.07345144 -0.03417888  0.06119534 -0.04169855
#  -0.22709662 -0.12329203  0.08782518 -0.05259509 -0.10497121 -0.02105464
#  -0.1833303   0.1163919  -0.03122422 -0.05424273  0.05894276  0.18350615
#   0.13458404  0.14669979  0.17402118 -0.16216609 -0.00370231  0.18525755
#  -0.05271553 -0.04458303  0.00318482 -0.07023259  0.12765492  0.10500992
#  -0.05835053 -0.1746435  -0.06040996 -0.02419589 -0.1422151   0.02507718
#  -0.09275158 -0.0491346   0.1238078   0.03885087  0.01008406  0.01241603
#   0.05099153 -0.10375454  0.06118485 -0.05280813  0.04813955  0.10381685
#  -0.0225897  -0.06281593  0.03364049 -0.00200234  0.08434307  0.06692792
#  -0.01819793 -0.10208338 -0.06198201  0.02585999 -0.06237202  0.03031592
#  -0.07519662  0.03699424]
# [-0.0441542  -0.11212809  0.10584492  0.02224449  0.119905   -0.13555238
#   0.08212062  0.02676605  0.00783733  0.10667839  0.1450447  -0.10704485
#  -0.06083243 -0.01502763  0.05013664  0.10218996 -0.03927374  0.00218313
#  -0.10948344  0.08112217  0.12811062  0.17363115  0.01348275 -0.08105246
#  -0.09195935  0.01188599 -0.05396282  0.10879136  0.10253904 -0.04670858
#  -0.09191201  0.08452924  0.03749491  0.00296975 -0.05402465  0.0683656
#   0.14164771 -0.00458445  0.10008644 -0.04738781 -0.05557783  0.09258412
#   0.00092168 -0.07393952  0.13966155  0.03182962 -0.02558331 -0.06867973
#  -0.09366237  0.06078212  0.14573464  0.09537567  0.00526855  0.02642885
#   0.02463985  0.05668672  0.2668536   0.01743056 -0.04757074  0.06428344
#  -0.1108742   0.00268051  0.13680802 -0.01514552  0.11914221 -0.05707057
#   0.08963807  0.049704   -0.03442775  0.0790775   0.05974345 -0.00258559
#  -0.18695086 -0.01744681  0.07284586 -0.07188169 -0.09351206 -0.0004179
#  -0.19464098  0.09535368 -0.04720619 -0.0811184   0.04319975  0.21890917
#   0.10671008  0.06497898  0.09649136 -0.16474016 -0.05743395  0.1090879
#  -0.08173362 -0.09775247 -0.02980321 -0.08505139  0.05766582  0.11452416
#  -0.05273437 -0.1848524  -0.05247197 -0.14463055 -0.07258783 -0.00910789
#  -0.10572406 -0.01768795  0.08372346 -0.04115626 -0.05020847  0.03301829
#  -0.03151102 -0.08549325  0.08742061  0.00880656  0.02640552  0.1737647
#  -0.07927037 -0.13660416 -0.01205687 -0.07746909  0.0333439   0.12055578
#   0.00071866 -0.08389102  0.03245611  0.03841581  0.04744649 -0.02941016
#  -0.05995609  0.00491375]
# [-0.00960458 -0.06277102  0.16904476 -0.01800151  0.03079484 -0.14565425
#   0.01344226  0.02416509  0.00970981  0.10933714  0.16244204 -0.02043143
#  -0.00921905 -0.0602522  -0.00035782  0.10877316  0.04145507  0.08281942
#   0.01043092  0.02951894  0.10024534  0.17295031  0.07330371 -0.19510739
#  -0.14617707  0.00924214  0.00181229  0.12884805  0.17039204 -0.03737747
#  -0.06469322  0.0990594  -0.13008414  0.04546123 -0.05346648 -0.03326807
#   0.08757376  0.00375416  0.07325391 -0.04253598  0.07652564  0.02569725
#  -0.05553701 -0.08958086  0.12678118  0.04086754 -0.06965703 -0.06190453
#  -0.09627214  0.06908917  0.13597447 -0.00844983  0.01052666  0.12585385
#   0.04893572 -0.06020255  0.17481093 -0.05217914 -0.07327737  0.05634828
#  -0.04921015 -0.06638374  0.14660016  0.01297811  0.09001575 -0.1868912
#   0.01900326  0.07844274  0.0882299   0.03131128  0.00438225 -0.02323218
#  -0.22059122 -0.00212539  0.01041071 -0.01157191  0.03334675  0.00442421
#  -0.19367091  0.17691216 -0.03240118 -0.03739487  0.00382447  0.14369301
#   0.18538189  0.04424137  0.13578059 -0.11197042  0.00674002  0.18202952
#  -0.10885642 -0.14338917 -0.12252051 -0.06064561  0.10020275 -0.00050369
#  -0.00896164 -0.17915994 -0.01333748 -0.03172734 -0.13528144 -0.02061202
#  -0.14277947 -0.0666955   0.11694552  0.04566847  0.02869033  0.00843509
#   0.03201257 -0.01556937  0.0228981  -0.05803731  0.04164796  0.12934387
#  -0.06152383  0.05062506  0.02646522  0.04226242  0.02900822  0.04265284
#  -0.0115472  -0.01364384 -0.05491569  0.03680613  0.00659715 -0.07296738
#  -0.07191628  0.03419047]
# [ 0.00682091 -0.15233806  0.06192327  0.02320434  0.06349859 -0.08979978
#   0.0051978   0.0390408  -0.02710207  0.18535753  0.09148571 -0.10060788
#  -0.03833865 -0.00563228  0.06326975  0.09420969 -0.06354459  0.06418
#  -0.11054839  0.09334232  0.11657076  0.11447532  0.00354845 -0.11319353
#  -0.11185797  0.03746523 -0.07273807  0.08849829  0.04531948 -0.06118392
#  -0.04937457  0.11078997  0.05417139 -0.03747923 -0.06524394  0.04326156
#   0.20317464 -0.00807261  0.06358014  0.05179502 -0.0034738   0.12451011
#  -0.06307762 -0.0560277   0.08257402  0.07575933 -0.1031302  -0.04181217
#   0.03915627  0.07572956  0.05184468  0.06384779  0.08812538  0.14601277
#  -0.00132482  0.02960167  0.17992029  0.01477971 -0.06982718  0.05036226
#  -0.05377588 -0.01708879  0.12259411  0.03139511  0.15361694 -0.04967521
#   0.047655    0.00931299 -0.06513587 -0.0568133   0.07765137 -0.06751876
#  -0.21161126 -0.09764866  0.1264907  -0.11091614 -0.1690475  -0.03928143
#  -0.1335762   0.11313429 -0.03726723 -0.0611122   0.05381117  0.19390193
#   0.14977826  0.19182928  0.1935285  -0.1426866   0.02806122  0.15431379
#  -0.08173723 -0.07888312  0.01112678 -0.01688717  0.12666352  0.11843514
#  -0.07084632 -0.17661564 -0.02635203 -0.04207725 -0.14430033  0.02124369
#  -0.06036996 -0.04628811  0.08925501  0.09073263  0.01264231  0.05079848
#   0.06859365 -0.10083615  0.06402779 -0.06225507  0.04049107  0.05870151
#  -0.0132338  -0.05424178  0.043667    0.01824577  0.05649656  0.07315268
#  -0.02522761 -0.10007335 -0.01935173  0.02424998 -0.05210419  0.00064788
#  -0.03942385  0.04893264]
# [ 0.06363423 -0.1290286  -0.05870556  0.11063711  0.07465617 -0.01821627
#  -0.02257561  0.09286666 -0.02618488  0.1380462   0.01571522 -0.06017404
#  -0.01879985 -0.05734134  0.04304993  0.07293021 -0.02573124  0.12334269
#  -0.09435166  0.10539638  0.10791675  0.04450468  0.02396537 -0.09600717
#  -0.01285219 -0.00583643 -0.12795906  0.07071585  0.04981221 -0.06353502
#  -0.0171774   0.1485229   0.05745541 -0.02477407 -0.02635931  0.09248554
#   0.2516762  -0.01669203  0.05558343  0.09608164 -0.01426471  0.1482626
#   0.01324833 -0.10058609  0.07264953  0.04005354 -0.09804001 -0.03870109
#   0.10532141  0.06056598 -0.02377127  0.03875171  0.07152998  0.15498652
#   0.06347497  0.07609159  0.09466118  0.02566383 -0.07292665 -0.00283366
#  -0.03274828  0.00984105  0.14200191  0.04730475  0.16764253 -0.01113823
#   0.05410219 -0.0154218  -0.0952592  -0.04971478  0.06971576 -0.10906919
#  -0.15577269 -0.16098215  0.13964082 -0.1378562  -0.204228   -0.05762826
#  -0.05889286  0.10443379  0.02695943 -0.10502096  0.03912001  0.0890526
#   0.16402395  0.22291009  0.17393848 -0.05779311  0.02235097  0.1054751
#  -0.01660774 -0.07794612  0.05599229  0.00268039  0.10642425  0.12465816
#  -0.07015733 -0.16714838 -0.00207876  0.04400261 -0.12371494  0.09230004
#   0.00043109 -0.04279282  0.14366093  0.09994943  0.02728221 -0.00694922
#   0.09034072 -0.12505178  0.0461163  -0.01472814  0.06089594 -0.00833017
#   0.10998292 -0.047831    0.10219207  0.04113341  0.09169419  0.04623828
#  -0.04345283 -0.10575759 -0.06807192 -0.01684668 -0.05860459  0.03348936
#   0.01278164  0.04219117]
# [ 0.02707152 -0.14496821  0.03564463  0.088341    0.06282465 -0.04944035
#  -0.00122772  0.0039832  -0.03391924  0.19103986  0.07547702 -0.08393846
#  -0.04521677 -0.02840771  0.0969437   0.09928398 -0.11558022  0.07543322
#  -0.1158236   0.08753692  0.07012969  0.09619438 -0.01920792 -0.12399181
#  -0.11239408  0.08392297 -0.08251553  0.08098522  0.03858329 -0.05813606
#   0.00071309  0.11145279  0.04440518 -0.02755342 -0.03422638  0.03362553
#   0.21366635 -0.02138271  0.02294214  0.02901245 -0.02539779  0.1152955
#  -0.04666192 -0.06306916  0.13734591  0.05329522 -0.11859631 -0.02882442
#   0.05729124  0.09840652  0.06862668  0.06539039  0.06245337  0.12795027
#  -0.0153377   0.05140466  0.1691698   0.04338331 -0.1017225   0.07373179
#  -0.073403   -0.02080356  0.14044696  0.0276636   0.17807339 -0.03844723
#   0.04065001 -0.0311775  -0.05035553 -0.0783998   0.05551115 -0.08741377
#  -0.21901347 -0.07709173  0.13504925 -0.10056196 -0.15124519 -0.0522201
#  -0.11930408  0.10503735 -0.02987652 -0.05944677  0.09240618  0.16671646
#   0.11328673  0.20695741  0.1684861  -0.13714525  0.05078596  0.11861941
#  -0.05517306 -0.03933913  0.02322167 -0.03391425  0.11069658  0.1257349
#  -0.05587167 -0.15592338 -0.02526856  0.00939395 -0.14316523  0.02600584
#  -0.06731054 -0.05395624  0.08370671  0.11742678  0.01488928  0.06943786
#   0.06522799 -0.09843186  0.09542552 -0.08963262  0.06451277  0.06690516
#  -0.01201673 -0.02665216  0.02259164  0.01473396  0.07182636  0.08210881
#  -0.04098469 -0.08529459 -0.06404244 -0.00840628 -0.04609925 -0.03230985
#  -0.07541955  0.0472161 ]
# [ 0.14579822 -0.05484387  0.02837168  0.10439456  0.00371696  0.09203061
#  -0.02575928 -0.0111986  -0.06981064  0.16369326  0.02378471 -0.0664824
#  -0.08488669  0.08181507  0.18647026  0.05070302 -0.17015497  0.04813078
#  -0.03148013  0.11936356  0.0444267   0.07847218 -0.05387529 -0.10699397
#  -0.1326136   0.1258679  -0.02229268  0.08961722 -0.00276309 -0.10171451
#  -0.04496201  0.10907736  0.03945309  0.05853791  0.02213639  0.03743379
#   0.17158517 -0.07161637  0.01011595 -0.02129284 -0.14032254  0.06284823
#  -0.05798106 -0.04722977  0.1468272   0.06017126 -0.06121074 -0.00354127
#  -0.02199454  0.06472916  0.0458448  -0.00253901  0.08163951  0.10770664
#  -0.00256765  0.0545475   0.14935075  0.08350417 -0.0957159   0.00238192
#   0.02494748 -0.06919596  0.11912452  0.02058673  0.17949185 -0.08196699
#  -0.05698584  0.02601745 -0.03254414 -0.06203481  0.03049876 -0.12024065
#  -0.23421648 -0.0586146   0.10535964 -0.14308013 -0.06584883 -0.07927231
#  -0.06126675  0.06556653 -0.04569587 -0.05736904  0.09951481  0.13774244
#  -0.02671993  0.17241666  0.15552188 -0.12755175  0.13278952  0.01035157
#  -0.07110202 -0.00940177  0.10007102 -0.06760073  0.10954268  0.1548036
#  -0.01852852 -0.07945991 -0.08250501  0.00601679 -0.04412641  0.0555542
#  -0.02858113 -0.04568702  0.00061733  0.08529063  0.01266315  0.15916465
#   0.13123766 -0.13076684  0.06363472 -0.0219167   0.06581336 -0.0223445
#  -0.02721887  0.10243332 -0.04192067  0.10523606  0.08470784  0.16865216
#  -0.04063034 -0.05457741 -0.08912385  0.02084516 -0.06801    -0.08813462
#  -0.09269606  0.05589821]
# [ 1.48819253e-01 -9.34165046e-02  6.00762293e-02  1.01968177e-01
#   3.78243178e-02  8.44996050e-02 -2.29237527e-02  1.36357993e-02
#  -3.78511660e-02  1.39550313e-01  7.62665868e-02 -1.75974779e-02
#  -4.42556404e-02  1.29251212e-01  1.97285146e-01  1.56675801e-02
#  -1.16496213e-01 -1.05543027e-03 -8.93780664e-02  1.35907769e-01
#   2.54618786e-02  6.82900399e-02 -1.64086800e-02 -5.88509403e-02
#  -7.04362839e-02  1.18928924e-01 -6.48173094e-02  8.21924433e-02
#  -2.11299211e-02 -5.71804717e-02 -1.65577643e-04  1.11792997e-01
#   3.10495831e-02  5.47993276e-03  5.71503639e-02  4.91458066e-02
#   1.69266060e-01 -8.46328586e-02 -7.14640506e-03 -5.98895922e-03
#  -1.64061204e-01  8.56043920e-02 -6.41139299e-02  3.16227078e-02
#   1.83218956e-01 -4.56229448e-02 -6.29192889e-02  1.78075302e-02
#  -5.48841953e-02  7.24911541e-02  6.75434843e-02  3.79317044e-03
#   9.65147838e-02  4.80224006e-02 -2.05505639e-02  1.02081619e-01
#   9.27981660e-02  8.33066180e-02 -9.79349464e-02 -4.03397307e-02
#  -1.46012232e-02 -4.62033935e-02  1.02129102e-01  2.43967082e-02
#   1.64723024e-01 -9.01704878e-02  1.05322879e-02  2.35241279e-02
#  -3.02433055e-02 -1.29350513e-01  4.86560762e-02 -1.91371426e-01
#  -2.21699432e-01 -2.15798267e-03  9.57350880e-02 -1.31980777e-01
#  -9.97842997e-02 -2.50272197e-03 -3.97555791e-02  1.33791581e-01
#  -7.63056278e-02 -7.58140311e-02  1.03083014e-01  1.05427548e-01
#  -7.15662390e-02  1.67440325e-01  2.13145375e-01 -1.13061875e-01
#   1.78218886e-01  7.87285250e-03 -9.14640725e-03  1.37283988e-02
#   8.30864459e-02 -5.09404130e-02  1.13760963e-01  9.59971845e-02
#  -9.63351317e-03 -8.70969146e-02 -1.09033011e-01  4.83918563e-02
#  -2.95175612e-02  3.08636166e-02 -1.03652917e-01 -5.19472882e-02
#  -3.72021012e-02  7.97328427e-02  5.35058090e-03  1.22179620e-01
#   1.33539975e-01 -4.88573462e-02  9.73533019e-02 -4.35066037e-02
#   7.57318139e-02  1.11857755e-03 -3.97218876e-02  6.56298697e-02
#  -7.85343274e-02  6.57691360e-02  1.19736440e-01  1.35653839e-01
#  -1.13603994e-02  4.38955519e-03 -1.00719720e-01  5.51180169e-03
#  -1.12864383e-01 -4.73534428e-02 -7.17007518e-02  7.32531771e-02]
# [ 2.12767608e-02 -1.47356898e-01  8.87722671e-02  9.85355675e-02
#   1.05070863e-02  3.70890126e-02 -7.78091362e-06 -2.99097672e-02
#  -7.15622231e-02  8.47771317e-02  1.28394634e-01 -4.73558791e-02
#  -7.59973526e-02 -4.86746281e-02  1.02675311e-01  7.62879029e-02
#  -1.70381248e-01  8.10232162e-02 -4.69666831e-02  8.83533955e-02
#   3.19781266e-02  4.31604907e-02 -5.44480048e-02 -1.29854128e-01
#  -1.87635183e-01  2.65600868e-02 -8.28172415e-02  1.47148892e-01
#   1.58746876e-02 -1.65363289e-02 -4.81013022e-03  7.11534768e-02
#  -4.27620625e-03  1.86202861e-02  7.73756718e-03  2.70944592e-02
#   2.01692238e-01 -5.44977514e-03  6.67607188e-02 -6.88455626e-02
#  -2.53263265e-02  8.28728303e-02  3.31439115e-02 -8.29899404e-03
#   2.51624554e-01  7.97919258e-02 -5.46538830e-02 -2.76681092e-02
#  -2.04682983e-02  6.34072423e-02  9.14198980e-02  1.16852224e-02
#  -2.99562830e-02  8.18886012e-02  6.26301691e-02  6.01874813e-02
#   2.04646856e-01  8.32580253e-02 -9.52932686e-02  1.07398801e-01
#  -1.39079645e-01  1.69570856e-02  1.74202740e-01  4.15520221e-02
#   1.05753541e-01  9.02393367e-03 -2.56182346e-02 -6.60824999e-02
#  -5.45596592e-02 -8.71592313e-02  3.31379920e-02 -9.06739309e-02
#  -2.34427258e-01 -9.15203467e-02  7.92024136e-02 -5.79573102e-02
#  -3.52088101e-02 -4.04846855e-02 -1.06590256e-01  1.31766513e-01
#  -2.99746711e-02 -3.20230164e-02  7.99683928e-02  2.11840242e-01
#   8.15233514e-02  1.33925289e-01  1.65956289e-01 -8.44684020e-02
#   8.82890970e-02  8.51736665e-02 -6.27381951e-02 -8.73453021e-02
#   3.15026157e-02 -9.18632597e-02  9.71176326e-02  1.60601020e-01
#  -8.70252475e-02 -1.01052605e-01 -1.25450686e-01  4.27284166e-02
#  -1.13326542e-01  5.57067692e-02 -9.53029692e-02  3.80237624e-02
#   8.07584375e-02  9.45203677e-02 -8.92565548e-02  4.27547060e-02
#  -3.62127535e-02 -1.02211133e-01  5.18699922e-02 -1.31901532e-01
#   7.27119595e-02  1.50622996e-02 -7.29144365e-02 -3.00601628e-02
#   1.89194679e-02  3.56503064e-03  4.07954641e-02  9.55052376e-02
#  -9.88820195e-03 -3.21396329e-02 -6.64146021e-02  6.03863709e-02
#  -3.27568576e-02 -4.24783006e-02 -5.16110770e-02 -2.37335749e-02]
# [ 0.03651321 -0.1425255   0.11639057  0.04665811  0.01604207 -0.00718338
#   0.0926211  -0.04514383 -0.04580455  0.12303779  0.12877175 -0.15439945
#  -0.12819561 -0.10343569  0.13725248 -0.04109284 -0.08473789  0.15071367
#   0.04393034  0.0021404  -0.02090668  0.0772677  -0.02721341 -0.05101426
#  -0.22201078 -0.03315146 -0.00933309  0.20330738 -0.03366131  0.05820095
#  -0.17896992  0.09052159  0.1017064   0.02861839 -0.0032835   0.04352256
#   0.16239105 -0.03843495  0.05788588 -0.11237138  0.04386925  0.01963598
#  -0.05314227 -0.02017845  0.1038601   0.00249469 -0.08659109 -0.06889988
#  -0.01315909  0.02605103  0.16955838 -0.04456025  0.00667039  0.03461106
#   0.00849591  0.03966722  0.14387175  0.06710903 -0.09986654  0.03490677
#  -0.1481132   0.00646186  0.16255754 -0.10781281  0.0401831   0.02561325
#  -0.0608728  -0.06185339 -0.08923493 -0.03117442  0.03580491 -0.11029032
#  -0.12468271 -0.11942767  0.03361841 -0.13740158 -0.06669085 -0.06883641
#  -0.12260888  0.02840474 -0.02649959 -0.06324555 -0.03468349  0.11018422
#   0.077232    0.02172725  0.18015684 -0.09929184  0.03986453  0.1266986
#  -0.1355959  -0.01098524  0.00056203  0.01302639  0.08775637  0.07961905
#  -0.16043656 -0.16785263 -0.11443888 -0.10293084 -0.09387969 -0.02931829
#  -0.04455608  0.0854245   0.05638254 -0.00453219 -0.04266609 -0.03743769
#  -0.11847823 -0.13794415  0.02818178 -0.14684361  0.06391598 -0.02911898
#  -0.0054752  -0.06279019  0.01282784  0.05300066 -0.02172761  0.11553976
#  -0.01087544 -0.0699582  -0.0888156   0.15560937 -0.05722007 -0.04275717
#   0.03558419  0.010359  ]
# [-0.00960458 -0.06277102  0.16904476 -0.01800151  0.03079484 -0.14565425
#   0.01344226  0.02416509  0.00970981  0.10933714  0.16244204 -0.02043143
#  -0.00921905 -0.0602522  -0.00035782  0.10877316  0.04145507  0.08281942
#   0.01043092  0.02951894  0.10024534  0.17295031  0.07330371 -0.19510739
#  -0.14617707  0.00924214  0.00181229  0.12884805  0.17039204 -0.03737747
#  -0.06469322  0.0990594  -0.13008414  0.04546123 -0.05346648 -0.03326807
#   0.08757376  0.00375416  0.07325391 -0.04253598  0.07652564  0.02569725
#  -0.05553701 -0.08958086  0.12678118  0.04086754 -0.06965703 -0.06190453
#  -0.09627214  0.06908917  0.13597447 -0.00844983  0.01052666  0.12585385
#   0.04893572 -0.06020255  0.17481093 -0.05217914 -0.07327737  0.05634828
#  -0.04921015 -0.06638374  0.14660016  0.01297811  0.09001575 -0.1868912
#   0.01900326  0.07844274  0.0882299   0.03131128  0.00438225 -0.02323218
#  -0.22059122 -0.00212539  0.01041071 -0.01157191  0.03334675  0.00442421
#  -0.19367091  0.17691216 -0.03240118 -0.03739487  0.00382447  0.14369301
#   0.18538189  0.04424137  0.13578059 -0.11197042  0.00674002  0.18202952
#  -0.10885642 -0.14338917 -0.12252051 -0.06064561  0.10020275 -0.00050369
#  -0.00896164 -0.17915994 -0.01333748 -0.03172734 -0.13528144 -0.02061202
#  -0.14277947 -0.0666955   0.11694552  0.04566847  0.02869033  0.00843509
#   0.03201257 -0.01556937  0.0228981  -0.05803731  0.04164796  0.12934387
#  -0.06152383  0.05062506  0.02646522  0.04226242  0.02900822  0.04265284
#  -0.0115472  -0.01364384 -0.05491569  0.03680613  0.00659715 -0.07296738
#  -0.07191628  0.03419047]
# [ 0.02897584 -0.1217516   0.1879789  -0.019661    0.0040223  -0.09238496
#   0.03812096 -0.03236389 -0.01134339  0.10991718  0.16056836 -0.08779724
#  -0.11809108  0.04709449  0.02762726  0.08829843 -0.10688894 -0.03102342
#  -0.0112103   0.06513716  0.08836638  0.1607134  -0.00878251 -0.16411263
#  -0.17753486  0.06501956 -0.04544465  0.1066464   0.0667965  -0.07822364
#  -0.02756845  0.03304403 -0.03334094  0.05786658  0.00734426 -0.00950369
#   0.10634949 -0.00189669  0.03873748 -0.10221055 -0.05413351  0.04760966
#  -0.03010359 -0.07650396  0.22950046  0.04917266 -0.01620633 -0.02498776
#  -0.12720789  0.10505052  0.11163565  0.04973179  0.00285836  0.06375983
#  -0.01009176  0.03609884  0.29792365  0.04095419 -0.1058066   0.07553736
#  -0.10928281 -0.02793159  0.1022488  -0.05680602  0.13661028 -0.01765996
#   0.03186632  0.04626468  0.00786715  0.01914046  0.0120244  -0.01302933
#  -0.20901969  0.00376819  0.0600033  -0.03703613  0.00630499 -0.02865467
#  -0.1947567   0.1378122  -0.05492419 -0.0518614   0.04095659  0.22702824
#   0.10341486  0.02367167  0.10660126 -0.16222806  0.0261722   0.09876557
#  -0.07193302 -0.06520246 -0.00368288 -0.10624766  0.10547367  0.0780364
#  -0.02498133 -0.1177695  -0.14634435 -0.09817933 -0.11316224  0.02550952
#  -0.1475165   0.00077494  0.07101912  0.00728041 -0.07357078  0.07906006
#  -0.04533903 -0.0226783   0.00438774 -0.05880095  0.04485696  0.12344246
#  -0.15802467 -0.01881433 -0.04426206  0.00636521  0.02455404  0.07780284
#  -0.02474699 -0.01083435 -0.05478232  0.00209617 -0.04340407 -0.04897656
#  -0.0458635   0.02105638]
# [ 0.02993385 -0.13046063  0.09677428  0.02935572  0.04989647 -0.0627257
#   0.03452219  0.0300325  -0.03744517  0.15351054  0.10287636 -0.10916497
#  -0.07631096 -0.02912109  0.08950043  0.09003491 -0.06584574  0.06437857
#  -0.08152969  0.06784479  0.10375699  0.15438552 -0.01020214 -0.13473357
#  -0.1525994   0.02591619 -0.06977817  0.10762154  0.05803736 -0.04236463
#  -0.06296103  0.07178441  0.01676003  0.00659742 -0.08312675  0.01814537
#   0.18679054 -0.00802523  0.06289539 -0.02029737 -0.0091378   0.09605563
#  -0.04684962 -0.0453965   0.14081852  0.05423063 -0.08546626 -0.03934401
#  -0.01522798  0.06535143  0.08557562  0.05680643  0.05473357  0.11094256
#   0.03071921  0.02293771  0.2416513   0.02001981 -0.07848145  0.06693725
#  -0.07848179 -0.03768133  0.13970605  0.01004397  0.1309748  -0.06881268
#   0.04327225  0.0130232  -0.0406541  -0.04603504  0.05618183 -0.06085264
#  -0.21581918 -0.07959405  0.09223738 -0.07966889 -0.10387794 -0.03519897
#  -0.16523358  0.11230048 -0.05582606 -0.07571543  0.06264916  0.23156591
#   0.11674086  0.11924991  0.17075658 -0.15584195  0.05631694  0.17313534
#  -0.10496844 -0.08877213 -0.01516012 -0.03866788  0.10733712  0.11160222
#  -0.07520425 -0.18689471 -0.06679925 -0.06761845 -0.12830713  0.02228525
#  -0.09495078 -0.03808311  0.10179381  0.05836527 -0.00556771  0.05785316
#   0.05010507 -0.07975821  0.05849755 -0.0606012   0.05259079  0.09681042
#  -0.07348252 -0.03054705  0.01545962  0.02670865  0.06647522  0.09682457
#  -0.02400504 -0.07595997 -0.02768909  0.03191721 -0.06701681 -0.02699505
#  -0.07316306  0.05896444]
# [ 0.01458408 -0.16564263  0.04707018  0.05412964  0.06861588 -0.06705387
#   0.02067877  0.03107843 -0.04754483  0.1807255   0.09204293 -0.08812606
#  -0.05515661 -0.0411352   0.06011722  0.0921937  -0.07482477  0.09787712
#  -0.12203983  0.07884417  0.09787977  0.09355225 -0.00770377 -0.11980521
#  -0.12404991  0.02397832 -0.07700128  0.11273285  0.0667555  -0.05517855
#  -0.03569506  0.08960582  0.05309749 -0.03361752 -0.06804985  0.0392258
#   0.22294992 -0.01120573  0.06729554  0.0428545   0.0227559   0.11675662
#  -0.03671473 -0.05147045  0.11031693  0.09003406 -0.10745602 -0.03801562
#   0.05902153  0.0706767   0.07990719  0.07219046  0.05638348  0.12769298
#   0.02734282  0.04649533  0.1800533   0.02736376 -0.07783727  0.07128467
#  -0.08120949 -0.01577648  0.13523887  0.03279269  0.1446467  -0.04419815
#   0.04479    -0.01659679 -0.05923723 -0.05506057  0.05490768 -0.07963584
#  -0.20553333 -0.10900211  0.10602041 -0.06971624 -0.14874315 -0.04617126
#  -0.12617321  0.12622495 -0.02069916 -0.06802815  0.05839108  0.18615408
#   0.15766771  0.18058117  0.18192205 -0.13225067  0.01936292  0.15671088
#  -0.08505841 -0.08693361  0.00765384 -0.04813464  0.12619396  0.1226595
#  -0.0821523  -0.18151943 -0.02240625 -0.02349317 -0.1358203   0.04997132
#  -0.0603939  -0.03186483  0.11012015  0.08658584  0.00291896  0.03210327
#   0.04743842 -0.09888168  0.07312757 -0.05748395  0.0539811   0.04858303
#  -0.00436338 -0.05815533  0.04299273  0.02284568  0.06484193  0.06170465
#  -0.03262481 -0.08907873 -0.03782983  0.03164816 -0.06028019 -0.01458442
#  -0.05344846  0.03017766]
# [-4.08819281e-02 -1.50284648e-01  1.67901754e-01 -3.22562158e-02
#   6.00464735e-03 -5.26444502e-02  4.21687588e-03  1.21372592e-04
#   1.70793175e-03  1.32705495e-01  1.34331912e-01 -3.28196287e-02
#  -6.46611229e-02  5.06040528e-02  8.89697224e-02  4.22148295e-02
#  -8.83750468e-02  5.74292764e-02 -4.48153988e-02  8.41889158e-02
#   7.04467222e-02  6.20295592e-02  3.23139206e-02 -1.68115422e-01
#  -1.46767780e-01 -8.48477986e-03  3.32171321e-02  2.00795501e-01
#   1.16681658e-01 -1.75199900e-02 -1.14369646e-01  7.26229474e-02
#  -9.96093750e-02  4.80841808e-02 -1.92864530e-03  1.63335893e-02
#   3.83609273e-02 -1.04061224e-01  9.72852036e-02 -8.69802758e-02
#   2.08304506e-02  4.83245868e-03 -4.40884903e-02 -6.08314853e-03
#   1.97623298e-01  4.43754308e-02 -4.33112867e-02 -8.36675800e-03
#  -1.07351094e-01  1.10340171e-01  5.67385964e-02  6.06607795e-02
#  -5.07228170e-03  3.58018205e-02 -9.42452550e-02 -5.66774420e-03
#   1.66633710e-01  9.16643068e-02 -9.53326598e-02  1.20323122e-01
#  -1.42324552e-01  1.03615366e-01  5.67356497e-02 -6.17048889e-02
#   8.24142843e-02  2.68973932e-02 -1.63485669e-02 -1.67981430e-03
#   3.62709351e-02 -3.48339416e-02  1.25112003e-02 -1.26185790e-02
#  -1.88020244e-01 -9.71551016e-02  3.62030156e-02 -1.04657739e-01
#   4.21088636e-02  1.05070630e-02 -1.21695474e-01  1.89039618e-01
#  -7.44856298e-02 -2.47292630e-02 -9.01682023e-03  1.78704217e-01
#   1.38587400e-01  4.76729199e-02  1.34345427e-01 -1.71110928e-01
#  -7.86781032e-03  2.97260322e-02 -6.27702028e-02 -1.31887227e-01
#   1.09707164e-02  1.91641122e-03  3.33217978e-02  1.00702509e-01
#  -1.54376924e-01 -1.41258016e-01 -1.69171825e-01 -6.96371496e-02
#  -1.24770261e-01  2.06479840e-02 -1.53791308e-01  5.82322711e-03
#   1.46311074e-01  1.06152825e-01 -2.25120336e-02  2.39270926e-02
#   5.07722087e-02  1.70947220e-02 -4.32953425e-02 -1.18496463e-01
#   9.39975679e-02  1.27138630e-01 -1.12288706e-01  4.10998464e-02
#   4.61534783e-03  8.72535408e-02  9.13817808e-03  6.39558658e-02
#  -1.25490669e-02  5.31064644e-02 -1.14580400e-01  4.41673584e-02
#  -7.65026286e-02 -4.58392687e-02 -4.32792939e-02  4.29383144e-02]
# [ 0.00782718 -0.0628166   0.05006762  0.07277787 -0.01194564 -0.00501181
#   0.04159649 -0.03012647 -0.09478903  0.04167638  0.13385987 -0.1014991
#  -0.0471842  -0.01723686  0.07232247  0.08095112 -0.15818341  0.04282524
#   0.010125    0.05691436 -0.00793042  0.14027327 -0.0622152  -0.03228409
#  -0.15378523  0.02816471 -0.05112867  0.11218964 -0.07302611  0.04602235
#   0.03672934  0.05611558  0.0580466  -0.01931155 -0.00565338 -0.01560794
#   0.22035512  0.04945524  0.0044767  -0.07587029 -0.03395401  0.07108328
#   0.04255199 -0.01235177  0.18197674  0.05224755 -0.0533783  -0.1273975
#   0.03597282  0.07252256  0.21478964  0.08351288  0.03581462  0.06684712
#   0.01718914  0.01225542  0.2891628   0.04682994 -0.05623219  0.09305937
#  -0.10446676 -0.04125848  0.15806799 -0.03330238  0.15606236 -0.09999251
#  -0.02301206 -0.04795987  0.00175518 -0.00382822  0.04541061 -0.02800907
#  -0.18755041  0.04814263  0.04417329 -0.03983462 -0.02665291 -0.00229904
#  -0.16523094  0.16365965 -0.01034002 -0.03082686  0.03683891  0.23111163
#   0.03654005  0.15568852  0.08944296 -0.0956921   0.06099562  0.11493427
#  -0.03076714 -0.00122324  0.02041035 -0.06379516  0.09957485  0.08299308
#  -0.1032575  -0.06799474 -0.06803896 -0.06815344 -0.10974809 -0.0321621
#  -0.11847974  0.05062957 -0.03019803  0.00953237 -0.02823256  0.10052391
#  -0.10284738 -0.10742061  0.17133409 -0.08865065  0.00487028  0.13481098
#  -0.13228491 -0.13498795  0.03082915 -0.04873021  0.02784322  0.13586389
#  -0.01820136 -0.03850404 -0.01066738 -0.03910424  0.04111744 -0.13026386
#  -0.04385432 -0.00153108]
# [ 0.03857455 -0.14296386  0.0715467   0.05179338  0.05240671 -0.07723304
#   0.0180848   0.03006535 -0.02105642  0.16282554  0.08994035 -0.10503643
#  -0.04913833 -0.00254136  0.0963544   0.09308335 -0.06274442  0.0639726
#  -0.11656448  0.09195003  0.11655957  0.14272808 -0.03082428 -0.14042957
#  -0.12525448  0.04799975 -0.08136976  0.06460176  0.07358147 -0.05417839
#  -0.04837008  0.10891861  0.0250569   0.00560042 -0.05996839  0.02529219
#   0.19647026 -0.01824504  0.04242796  0.01541632 -0.02179433  0.11171549
#  -0.02951922 -0.04580699  0.12531498  0.05751074 -0.10654077 -0.05294553
#   0.00242652  0.08525953  0.07627764  0.04978538  0.06528039  0.12107302
#   0.00850302  0.02832595  0.20457707  0.02651767 -0.09700619  0.07477127
#  -0.07350557 -0.0178125   0.13704713  0.0072328   0.14827804 -0.07609781
#   0.04223658  0.00980603 -0.03795816 -0.03831541  0.05133262 -0.03410181
#  -0.23917311 -0.08961464  0.11067346 -0.09490472 -0.1166399  -0.04012697
#  -0.17502151  0.10752697 -0.04956504 -0.0963634   0.07767954  0.20383796
#   0.1344468   0.14752755  0.17822798 -0.14973986  0.03751255  0.15244362
#  -0.08940104 -0.07352948 -0.00456073 -0.03360599  0.12619913  0.1295068
#  -0.04938403 -0.17435479 -0.0515804  -0.05406146 -0.10593497  0.01425176
#  -0.07543886 -0.03972827  0.08512447  0.06013541  0.00484201  0.08179712
#   0.08305921 -0.07919328  0.07127225 -0.05291085  0.06268786  0.08196463
#  -0.04990684 -0.01428457  0.00897405  0.0228208   0.07427276  0.07134158
#  -0.02760275 -0.07349596 -0.01794416 -0.00233293 -0.05194119 -0.0130292
#  -0.0723561   0.07078506]
# [ 0.02058604 -0.10495127  0.1031385   0.03455951  0.10975726 -0.0208151
#  -0.02569196 -0.02374852 -0.13120714  0.03770607  0.07688996 -0.18036427
#  -0.08927652 -0.01322991  0.01044856  0.10977656 -0.05089553  0.05004786
#  -0.05144705 -0.00488009  0.04683586  0.10229509  0.03197713 -0.11898752
#  -0.16778253  0.07932662 -0.12590784  0.10810293 -0.00334154  0.01097745
#  -0.09260819  0.11115867 -0.05488755  0.03859124 -0.06019008  0.0147512
#   0.22695607  0.03322068  0.05227434  0.01726311  0.05587921 -0.00239922
#   0.01008183  0.00189493  0.11461444  0.02625642 -0.05312455 -0.13256714
#  -0.08969635  0.01925877  0.03811492  0.0649331   0.04895016  0.12751366
#   0.07712795 -0.03076651  0.15017332  0.02900358 -0.08666204  0.09360246
#  -0.04224161 -0.12545235  0.29378134  0.1184326   0.03654688 -0.02869962
#   0.06118789 -0.1252457  -0.04927829 -0.09957868 -0.01500981 -0.04975722
#  -0.19279222 -0.1056604   0.06960877 -0.05341071 -0.03160194 -0.06136332
#  -0.13755617  0.07822327 -0.05785878  0.00532817  0.05785726  0.1260097
#   0.023491    0.05031471  0.13849941  0.00548179  0.03929284  0.17637621
#  -0.12866013 -0.08230866 -0.10454027 -0.11435201  0.10163686  0.096684
#  -0.0479447  -0.11615627 -0.0728727   0.07922249  0.05596755 -0.05798528
#  -0.08288571 -0.04158698  0.11432912  0.09404614 -0.07896066  0.07208716
#   0.11425912 -0.03987915  0.00745301 -0.07513808  0.08410487 -0.01930426
#  -0.06960802  0.04570999 -0.07409611 -0.05038596  0.04777346  0.13742971
#   0.01073838 -0.05057762 -0.04472015  0.09860807 -0.00843475 -0.07886633
#  -0.19673502  0.04711746]
# [ 1.71085994e-05 -1.58520222e-01  9.34343040e-02  3.53680477e-02
#   4.71392460e-02 -5.83533384e-02  2.04807948e-02 -2.44420096e-02
#  -3.01632844e-02  1.70103997e-01  1.03463307e-01 -8.19203556e-02
#  -4.66241874e-02 -2.68975552e-02  7.56791607e-02  1.03693962e-01
#  -1.18586168e-01  6.53836578e-02 -1.13055505e-01  5.86436875e-02
#   6.89932182e-02  1.11677177e-01 -4.17479649e-02 -1.42321125e-01
#  -1.87858135e-01  4.50136065e-02 -4.97174859e-02  1.01539448e-01
#   3.93773280e-02 -2.30201557e-02 -1.89974550e-02  6.55383766e-02
#   3.84168625e-02 -1.23331025e-02 -5.76190799e-02 -1.98648358e-03
#   1.88534483e-01  4.53753257e-03  5.18752635e-02 -9.29485820e-03
#   1.53911514e-02  1.04719810e-01 -5.43348491e-02 -2.04675328e-02
#   1.47339806e-01  8.66675451e-02 -1.11035638e-01 -4.93601374e-02
#   4.65122759e-02  6.76288977e-02  9.72668529e-02  7.21654445e-02
#   4.96419072e-02  1.30916953e-01 -2.64237542e-02  1.39826750e-02
#   2.12243304e-01  3.41228768e-02 -9.83846933e-02  1.13267973e-01
#  -1.23579822e-01 -4.13243053e-03  1.35503858e-01  1.08960988e-02
#   1.27010927e-01 -4.30067927e-02  9.40334238e-03 -1.98035873e-02
#  -5.03978990e-02 -6.97782263e-02  5.92605174e-02 -4.94397357e-02
#  -2.34675571e-01 -6.51323795e-02  1.24599524e-01 -5.58493435e-02
#  -9.09014493e-02 -4.92250025e-02 -1.41676769e-01  9.56498310e-02
#  -5.18748797e-02 -6.39497116e-02  6.58958107e-02  2.24120796e-01
#   1.33029237e-01  1.63882241e-01  1.56467021e-01 -1.52038604e-01
#   5.51947281e-02  1.50192469e-01 -9.82089713e-02 -5.48664108e-02
#  -8.81367363e-03 -3.18352468e-02  1.04062706e-01  1.09542727e-01
#  -6.79403394e-02 -1.72423735e-01 -3.38109434e-02 -3.18288058e-02
#  -1.42753959e-01  3.45736444e-02 -7.60970116e-02 -2.50420067e-02
#   9.35475826e-02  9.21893343e-02 -7.36827264e-03  6.23606630e-02
#   5.27345762e-02 -6.44981787e-02  6.81810528e-02 -1.03480950e-01
#   4.06500846e-02  7.70472139e-02 -4.82502207e-02 -4.22257483e-02
#   5.58408909e-03  2.50913128e-02  6.03046678e-02  5.51113151e-02
#  -3.60054635e-02 -6.27637431e-02 -4.36348245e-02  1.96045283e-02
#  -7.60387927e-02 -2.86284648e-02 -7.70124644e-02  4.77802679e-02]
# [-0.02811995 -0.05467097  0.11634191 -0.02066888  0.09842115 -0.12086485
#   0.04506271  0.03802806  0.04402254  0.1147643   0.14257377 -0.09954567
#   0.00830017 -0.03708335  0.03230702  0.04344257  0.02074178  0.01703484
#  -0.02266597  0.09351791  0.14389853  0.13582738  0.00327356  0.01795039
#  -0.02661564  0.03881756 -0.03754805  0.05338032  0.12440989 -0.08805054
#   0.03832801  0.10530576  0.04566806  0.04117333 -0.10559181 -0.0439037
#   0.10086163  0.04484602 -0.00796388 -0.05833783 -0.00479222  0.13186821
#  -0.02519636 -0.02307607  0.17713241  0.06322572  0.03465682 -0.03227387
#  -0.06812242  0.05313435  0.04897645  0.12287726  0.05273634  0.07825524
#  -0.06745112  0.03026453  0.2193102   0.1095451  -0.05669205  0.09224685
#  -0.0500059  -0.02715284  0.09440695 -0.05169339  0.17686026 -0.11604249
#   0.06674287  0.04521809  0.06809678  0.0762032   0.06390568 -0.09371992
#  -0.18390194  0.01234535  0.00431624  0.02430706 -0.09930401 -0.03064227
#  -0.24041401  0.10035084 -0.02564329 -0.11896802  0.08021128  0.24745579
#   0.09581112  0.14758791  0.01884785 -0.23378313 -0.0049419   0.09768596
#  -0.11158781 -0.07027029 -0.01382614 -0.01637449  0.02423962  0.03746738
#  -0.0390105  -0.06634967 -0.05088278 -0.12983419 -0.17152333 -0.00112014
#  -0.13045368 -0.01014787  0.11326505  0.03743396 -0.01417653  0.0241025
#   0.01885222 -0.05660421  0.13972984 -0.04746715  0.07248968  0.15032625
#  -0.06115452 -0.13686226  0.03308681 -0.08402535  0.07680642  0.10402332
#  -0.04835844 -0.05568838  0.03242318 -0.09811702 -0.04196681 -0.00767739
#  -0.0720801   0.04575153]
# [ 0.04577486 -0.14116794  0.10179134  0.03553162  0.02618521 -0.0355403
#   0.01062856  0.03781684 -0.05731761  0.12477262  0.10575835 -0.09150739
#  -0.07094149 -0.01750912  0.12129588  0.08669616 -0.05464652  0.08596625
#  -0.06098474  0.07442015  0.09640651  0.14471875 -0.02025276 -0.14524147
#  -0.16781878  0.02705021 -0.0695546   0.09150054  0.06314039 -0.03472718
#  -0.09093685  0.08684643 -0.00311242  0.01867871 -0.0732771   0.03186629
#   0.19647501 -0.01428123  0.07725779 -0.01782509 -0.0349442   0.08270141
#  -0.02547408 -0.02596044  0.14990684  0.05381842 -0.08578895 -0.0672789
#  -0.03157689  0.07136259  0.07907976  0.02822459  0.06847615  0.11807052
#   0.04559547  0.03958281  0.22875158  0.03484883 -0.09122445  0.04801615
#  -0.07150804 -0.05643922  0.15595345  0.00844316  0.1246639  -0.06312262
#   0.03009727  0.01026909 -0.03767905 -0.06512898  0.04471537 -0.05438203
#  -0.23259807 -0.09462503  0.0862496  -0.10684651 -0.08724543 -0.01606949
#  -0.15106337  0.12557946 -0.05076698 -0.07246084  0.06441889  0.221964
#   0.09640948  0.10691287  0.1935831  -0.12453517  0.08803039  0.1420253
#  -0.09559176 -0.09307236 -0.00202531 -0.04965003  0.12656964  0.1242962
#  -0.09410228 -0.1809602  -0.10684426 -0.04318309 -0.09094668  0.02584725
#  -0.10040325 -0.01165107  0.08686558  0.04261325 -0.01032191  0.0353575
#   0.04827809 -0.09353329  0.05285939 -0.06347557  0.07794358  0.06361552
#  -0.07994193 -0.00239973  0.01360389  0.04080158  0.0793105   0.09007967
#  -0.02620552 -0.04838964 -0.02119282  0.04730916 -0.06559409 -0.03707729
#  -0.08787289  0.05437453]
# [ 3.02647557e-02 -8.69756937e-02  6.63807392e-02  6.16651354e-03
#  -7.11236754e-03 -1.09544657e-01  4.94249305e-03  1.72475725e-01
#   3.02599762e-02  1.73781458e-02  1.04432099e-01 -6.13242798e-02
#  -8.01955834e-02  1.73824898e-03  1.52967107e-02  1.14132953e-03
#   1.05292380e-01  6.69288263e-02 -6.88215047e-02  6.05313405e-02
#   1.50767356e-01  1.98033571e-01  7.44680539e-02 -1.06657468e-01
#  -1.87097415e-02 -2.99559124e-02 -1.29289657e-01  3.25427279e-02
#   5.93386255e-02 -5.86641841e-02 -1.21251740e-01  8.12558830e-02
#  -4.41986322e-02 -2.07866021e-02 -7.39498585e-02  7.77985435e-03
#   2.34555528e-01 -5.42440899e-02  8.58431682e-02  1.19791301e-02
#  -1.25008274e-03  1.48982182e-01  7.55642541e-05 -9.57228988e-02
#   5.41940257e-02 -2.74102353e-02 -5.97289205e-02 -4.15535383e-02
#  -3.62700745e-02  8.59515145e-02 -1.75234172e-02  9.88664664e-03
#   2.47870721e-02  8.89410004e-02  1.51402861e-01 -4.13711322e-03
#   1.33676246e-01 -1.66455787e-02 -1.57178845e-02  1.19221173e-01
#  -4.56471276e-03 -1.57633815e-02  3.32119986e-02 -7.92530552e-03
#   9.08267200e-02 -1.12943485e-01  6.43684641e-02  4.61619571e-02
#   1.40984170e-02  2.17583664e-02  6.97092190e-02  5.86591326e-02
#  -1.44765198e-01 -1.56274527e-01  5.46005480e-02 -6.64125830e-02
#  -1.22121781e-01 -2.09223796e-02 -1.49840906e-01  3.60764079e-02
#   2.84676701e-02 -1.94765911e-01  7.33245090e-02  2.13301837e-01
#   1.37073696e-01  3.37502249e-02  1.11106165e-01 -1.28889889e-01
#  -4.68936637e-02  2.04525590e-01 -5.32287620e-02 -1.33062720e-01
#  -1.25859916e-01 -3.49402763e-02  1.70122266e-01  8.33330676e-02
#  -2.61269491e-02 -1.69538826e-01 -7.73900747e-02  2.57371478e-02
#  -5.16138189e-02  4.53732684e-02 -1.87373429e-03 -2.08452884e-02
#   1.61006048e-01  6.92574587e-03  7.82871470e-02  9.85567346e-02
#   8.73983651e-02 -7.06001595e-02 -4.78670858e-02 -4.51617092e-02
#   5.44085540e-02  1.52692854e-01 -5.98872155e-02  4.39548306e-02
#   7.42759332e-02  9.77702513e-02  5.46742789e-02  1.09542450e-02
#  -3.45352106e-02 -7.04156160e-02  3.52940187e-02 -6.87092990e-02
#   1.98547207e-02  5.08077741e-02 -7.30163828e-02  1.72254100e-01]

# %% [markdown]
# ### Let's write code to convert each tweet to its corresponding 2D array represenatation.
#
# Suppose we set tweet max length (max number of tokens taken into account per tweet)   =  20
#
# #### In this case, then ***each tweet can be represented as a 20 by 128 2D array/matrix.***
#
# How to convert a particular tweet to its corresponding 20 by 128 matrix?    See the example code below.

# %%
max_tweet_length = 20
vector_size = 128

tweet0 = np.zeros((max_tweet_length, 
              vector_size), dtype= np.float32)

# %%
for t, token in enumerate(tweets[0]):
        if t >= max_tweet_length:
            break
        if token not in model.wv:
            continue
        tweet0[t, :] = model.wv[token]

# %%
tweet0
# Out:
# array([[ 1.52721088e-02, -1.36253178e-01,  5.63252680e-02, ...,
#          3.03159244e-02, -7.51966238e-02,  3.69942449e-02],
#        [-4.41542044e-02, -1.12128094e-01,  1.05844922e-01, ...,
#         -2.94101648e-02, -5.99560887e-02,  4.91375476e-03],
#        [-9.60457511e-03, -6.27710223e-02,  1.69044763e-01, ...,
#         -7.29673803e-02, -7.19162822e-02,  3.41904685e-02],
#        ...,
#        [ 2.05860417e-02, -1.04951270e-01,  1.03138499e-01, ...,
#         -7.88663253e-02, -1.96735024e-01,  4.71174568e-02],
#        [ 1.71085994e-05, -1.58520222e-01,  9.34343040e-02, ...,
#         -2.86284648e-02, -7.70124644e-02,  4.77802679e-02],
#        [-2.81199496e-02, -5.46709746e-02,  1.16341911e-01, ...,
#         -7.67739443e-03, -7.20800981e-02,  4.57515270e-02]], dtype=float32)

# %%
tweet0.shape
# Out:
# (20, 128)

# %% [markdown]
# ### Now aggregate such 2D arrays for all the tweets and you will get the input data ready in 3D shape (i.e., X) for model training.   Super cool right?  Here is the sample code to get you X and Y for model training.

# %%
### Create train and test sets

# Generate random indexes
indexes = set(np.random.choice(num_of_tweets, num_of_tweets, replace=False))

X = np.zeros((num_of_tweets, max_tweet_length, vector_size), dtype= np.float32)
Y = np.zeros((num_of_tweets, 2), dtype= np.float32)

for i, index in enumerate(indexes):
    for t, token in enumerate(tweets[index]):
        if t >= max_tweet_length:
            break
        
        if token not in model.wv:
            continue
        
        X[i, t, :] = model.wv[token]
        
            
    Y[i, :] = [1.0, 0.0] if tweets[index] == 0 else [0.0, 1.0]    
    
    
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=1)
